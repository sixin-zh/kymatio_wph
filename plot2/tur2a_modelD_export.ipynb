# %%
import matplotlib.pyplot as plt
import do_plot_get2 as dpg
import numpy as np

import os,sys,datetime
import traceback

reload(dpg)

folds = 10

Ns = 256
S = 10
maxKrec=S
Ksel=maxKrec
droot1='./out/'
start0 = 5
hRUNFOL = './tur2a/bump_lbfgs_gpu_N256J5L8dj1dldk0_factr10maxite500maxcor20_initnormalstdbarx'
hptfile = 'eval_wph2_isonoref_norml_stdnorm1'

import scipy.io as sio
for fol in range(folds):
    kstart=fol+1
    imgs_pt=dpg.get_kymatio_pt(droot1,hRUNFOL,hptfile,Ns,kstart,maxKrec,Ksel,start0=start0,nbstart=10)
    ofile = './synthesis/tur2a_modelD_synthesis_ks' + str(kstart-1) +'.mat'
    sio.savemat (ofile , {'imgs':imgs_pt})
# Out:
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start5.pt')
# ('sel loss', 8.771092325332574e-08)
# ('sel loss', 9.901263183564878e-08)
# ('sel loss', 1.1150546924909577e-07)
# ('sel loss', 1.3161468814359978e-07)
# ('sel loss', 1.359812631562818e-07)
# ('sel loss', 1.436346246919129e-07)
# ('sel loss', 1.804554631235078e-07)
# ('sel loss', 1.8249022105010226e-07)
# ('sel loss', 3.334252687636763e-07)
# ('sel loss', 3.805829328484833e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start5.pt')
# ('sel loss', 8.987717592390254e-08)
# ('sel loss', 1.3723156371270307e-07)
# ('sel loss', 1.6370555385947228e-07)
# ('sel loss', 1.9392477042856627e-07)
# ('sel loss', 2.0838284399360417e-07)
# ('sel loss', 2.4092696548905224e-07)
# ('sel loss', 2.494129876140505e-07)
# ('sel loss', 2.6377580070402473e-07)
# ('sel loss', 3.7472069379873575e-07)
# ('sel loss', 3.9334488974418494e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start5.pt')
# ('sel loss', 7.342516710195923e-08)
# ('sel loss', 1.63105723913759e-07)
# ('sel loss', 1.824739774747286e-07)
# ('sel loss', 1.8901278963312508e-07)
# ('sel loss', 2.2235790311242454e-07)
# ('sel loss', 2.547402800701093e-07)
# ('sel loss', 2.70492018898949e-07)
# ('sel loss', 3.4893706470029427e-07)
# ('sel loss', 3.7853544199606403e-07)
# ('sel loss', 4.941798761137761e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start5.pt')
# ('sel loss', 6.491935437225039e-08)
# ('sel loss', 7.304576229216763e-08)
# ('sel loss', 8.295859515783377e-08)
# ('sel loss', 1.0640138498274609e-07)
# ('sel loss', 1.1208958312636242e-07)
# ('sel loss', 1.199610596813727e-07)
# ('sel loss', 1.5976424037944527e-07)
# ('sel loss', 1.7668475265963935e-07)
# ('sel loss', 1.8035125322057865e-07)
# ('sel loss', 2.304936060681939e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start5.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_