# %%
import matplotlib.pyplot as plt
import do_plot_get2 as dpg
import numpy as np

import os,sys,datetime
import traceback

reload(dpg)

folds = 10

Ns = 256
S = 10
maxKrec=S
Ksel=maxKrec
droot1='./out/'
start0 = 10
hRUNFOL = './tur2a/bump_lbfgs_gpu_N256J5L8dj0dl4dk0dn2_maxkshift1_factr10maxite500maxcor20_initnormalstdbarx'
hptfile = 'modelB'

import scipy.io as sio
for fol in range(folds):
    kstart=fol+1
    imgs_pt=dpg.get_kymatio_pt(droot1,hRUNFOL,hptfile,Ns,kstart,maxKrec,Ksel,start0=start0,nbstart=10)
    ofile = './synthesis/tur2a_modelB_synthesis_ks' + str(kstart-1) +'.mat'
    sio.savemat (ofile , {'imgs':imgs_pt})
# Out:
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 4.86861215904355e-05)
# ('sel loss', 5.221035797148943e-05)
# ('sel loss', 5.4020709358155726e-05)
# ('sel loss', 5.799965932965279e-05)
# ('sel loss', 6.596466060727835e-05)
# ('sel loss', 6.823602598160505e-05)
# ('sel loss', 7.196303922683001e-05)
# ('sel loss', 7.229641545563936e-05)
# ('sel loss', 7.973097264766693e-05)
# ('sel loss', 9.817773476243019e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 6.18807366117835e-05)
# ('sel loss', 6.608647294342518e-05)
# ('sel loss', 7.084837649017573e-05)
# ('sel loss', 7.214028853923082e-05)
# ('sel loss', 7.423388306051492e-05)
# ('sel loss', 7.711112499237061e-05)
# ('sel loss', 8.216418325901031e-05)
# ('sel loss', 8.26712977141142e-05)
# ('sel loss', 8.358603343367577e-05)
# ('sel loss', 9.13841649889946e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 3.7858039140701296e-05)
# ('sel loss', 4.227908328175545e-05)
# ('sel loss', 4.447110462933779e-05)
# ('sel loss', 4.589035641402006e-05)
# ('sel loss', 4.92650642991066e-05)
# ('sel loss', 5.081899464130402e-05)
# ('sel loss', 5.082814022898674e-05)
# ('sel loss', 5.16388425603509e-05)
# ('sel loss', 5.41966175660491e-05)
# ('sel loss', 5.481351632624865e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 4.870313219726085e-05)
# ('sel loss', 4.885889589786529e-05)
# ('sel loss', 6.102635059505701e-05)
# ('sel loss', 6.236040964722633e-05)
# ('sel loss', 6.601561326533557e-05)
# ('sel loss', 6.683921907097101e-05)
# ('sel loss', 7.082059048116207e-05)
# ('sel loss', 7.118450012058019e-05)
# ('sel loss', 7.149838376790284e-05)
# ('sel loss', 8.020119741559029e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 5.6154835037887095e-05)
# ('sel loss', 6.0543622821569444e-05)
# ('sel loss', 6.252324208617211e-05)
# ('sel loss', 6.68393587693572e-05)
# ('sel loss', 7.124312687665225e-05)
# ('sel loss', 7.242076098918915e-05)
# ('sel loss', 7.3700868524611e-05)
# ('sel loss', 7.987841963768006e-05)
# ('sel loss', 8.877525106072426e-05)
# ('sel loss', 9.384683333337307e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 3.086846554651856e-05)
# ('sel loss', 4.293813370168209e-05)
# ('sel loss', 4.5550535432994365e-05)
# ('sel loss', 4.657917190343141e-05)
# ('sel loss', 5.064054392278195e-05)
# ('sel loss', 6.000724621117115e-05)
# ('sel loss', 6.288789678364993e-05)
# ('sel loss', 6.938330829143524e-05)
# ('sel loss', 7.584530394524335e-05)
# ('sel loss', 8.063510991632938e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 3.393557388335466e-05)
# ('sel loss', 4.2736381292343136e-05)
# ('sel loss', 4.916743841022253e-05)
# ('sel loss', 4.9858433194458484e-05)
# ('sel loss', 5.0867525860667225e-05)
# ('sel loss', 5.129692144691944e-05)
# ('sel loss', 5.988994147628546e-05)
# ('sel loss', 6.129021290689707e-05)
# ('sel loss', 6.5598264336586e-05)
# ('sel loss', 7.186214905232191e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 3.2376851886510847e-05)
# ('sel loss', 3.8883460219949484e-05)
# ('sel loss', 4.051493015140295e-05)
# ('sel loss', 4.330257885158062e-05)
# ('sel loss', 4.45245485752821e-05)
# ('sel loss', 4.4958372600376604e-05)
# ('sel loss', 4.624861292541027e-05)
# ('sel loss', 5.085497163236141e-05)
# ('sel loss', 5.2422117441892624e-05)
# ('sel loss', 5.605853162705898e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 3.134626429527998e-05)
# ('sel loss', 5.4428353905677795e-05)
# ('sel loss', 5.6330626830458644e-05)
# ('sel loss', 5.763389635831118e-05)
# ('sel loss', 6.332230288535356e-05)
# ('sel loss', 6.506840232759714e-05)
# ('sel loss', 6.527344696223736e-05)
# ('sel loss', 6.577255669981241e-05)
# ('sel loss', 7.635978981852531e-05)
# ('sel loss', 9.786948561668396e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 3.810972208157182e-05)
# ('sel loss', 5.079709459096193e-05)
# ('sel loss', 5.599935073405504e-05)
# ('sel loss', 7.106817327439785e-05)
# ('sel loss', 8.14781617373228e-05)
# ('sel loss', 8.396819233894348e-05)
# ('sel loss', 8.408066816627979e-05)
# ('sel loss', 9.065669029951096e-05)
# ('sel loss', 9.732543490827084e-05)
# ('sel loss', 0.00010611637495458126)
