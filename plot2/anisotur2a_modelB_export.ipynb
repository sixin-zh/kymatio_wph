# %%
import matplotlib.pyplot as plt
import do_plot_get2 as dpg
import numpy as np

import os,sys,datetime
import traceback

reload(dpg)

folds = 10

Ns = 256
S = 10
maxKrec=S
Ksel=maxKrec
droot1='./out/'
start0 = 10
hRUNFOL = './anisotur2a/bump_lbfgs_gpu_N256J5L8dj0dl4dk0dn2_maxkshift1_factr10maxite500maxcor20_initnormalstdbarx'
hptfile = 'modelB'

import scipy.io as sio
for fol in range(folds):
    kstart=fol+1
    imgs_pt=dpg.get_kymatio_pt(droot1,hRUNFOL,hptfile,Ns,kstart,maxKrec,Ksel,start0=start0,nbstart=10)
    ofile = './synthesis/anisotur2a_modelB_synthesis_ks' + str(kstart-1) +'.mat'
    sio.savemat (ofile , {'imgs':imgs_pt})
# Out:
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 2.8442295733839273e-05)
# ('sel loss', 2.9612649232149124e-05)
# ('sel loss', 3.123263362795115e-05)
# ('sel loss', 3.365791635587811e-05)
# ('sel loss', 3.6600995808839795e-05)
# ('sel loss', 3.785343375056982e-05)
# ('sel loss', 3.951377235352993e-05)
# ('sel loss', 4.240218084305525e-05)
# ('sel loss', 4.712823312729597e-05)
# ('sel loss', 5.4466752335429195e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 2.8485136572271585e-05)
# ('sel loss', 3.1820472795516256e-05)
# ('sel loss', 3.19214747287333e-05)
# ('sel loss', 3.586777485907078e-05)
# ('sel loss', 3.587242681533098e-05)
# ('sel loss', 3.736820537596941e-05)
# ('sel loss', 3.817079355940223e-05)
# ('sel loss', 3.961073700338602e-05)
# ('sel loss', 5.01828920096159e-05)
# ('sel loss', 5.459005013108254e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 2.6661104056984188e-05)
# ('sel loss', 3.062292002141476e-05)
# ('sel loss', 3.7176699843257664e-05)
# ('sel loss', 3.7671674508601424e-05)
# ('sel loss', 3.9180065505206586e-05)
# ('sel loss', 3.9762547239661216e-05)
# ('sel loss', 4.1356333531439306e-05)
# ('sel loss', 4.176196176558733e-05)
# ('sel loss', 4.2371926829218866e-05)
# ('sel loss', 5.91591838747263e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 1.925809890963137e-05)
# ('sel loss', 2.0567949395626783e-05)
# ('sel loss', 2.226370619609952e-05)
# ('sel loss', 2.2993674501776696e-05)
# ('sel loss', 3.1485017389059066e-05)
# ('sel loss', 3.268164815381169e-05)
# ('sel loss', 3.272339701652527e-05)
# ('sel loss', 3.352428553625941e-05)
# ('sel loss', 3.939980175346136e-05)
# ('sel loss', 4.216819070279598e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 2.311722841113806e-05)
# ('sel loss', 2.7002140413969755e-05)
# ('sel loss', 2.9431835282593966e-05)
# ('sel loss', 3.071073442697525e-05)
# ('sel loss', 3.184773027896881e-05)
# ('sel loss', 3.185243345797062e-05)
# ('sel loss', 3.582404926419258e-05)
# ('sel loss', 3.61840333789587e-05)
# ('sel loss', 3.7508939858525994e-05)
# ('sel loss', 5.644162651151419e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 2.0187597256153824e-05)
# ('sel loss', 2.1174568682909012e-05)
# ('sel loss', 2.530839992687106e-05)
# ('sel loss', 2.6256339624524115e-05)
# ('sel loss', 2.7751135639846325e-05)
# ('sel loss', 2.801387570798397e-05)
# ('sel loss', 2.9338009189814328e-05)
# ('sel loss', 2.9714943375438453e-05)
# ('sel loss', 3.287733066827059e-05)
# ('sel loss', 4.767793230712414e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 1.8598403548821808e-05)
# ('sel loss', 2.3002047091722487e-05)
# ('sel loss', 2.598874969407916e-05)
# ('sel loss', 2.6328819803893566e-05)
# ('sel loss', 2.6815531309694052e-05)
# ('sel loss', 2.8104328084737062e-05)
# ('sel loss', 3.194157499819994e-05)
# ('sel loss', 3.6459218244999646e-05)
# ('sel loss', 3.784454427659511e-05)
# ('sel loss', 4.171698354184627e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 2.3509885650128127e-05)
# ('sel loss', 2.55197798833251e-05)
# ('sel loss', 3.255384508520365e-05)
# ('sel loss', 3.470542840659618e-05)
# ('sel loss', 3.5177813842892646e-05)
# ('sel loss', 3.559229662641883e-05)
# ('sel loss', 3.795777913182974e-05)
# ('sel loss', 3.8693214301019906e-05)
# ('sel loss', 4.2761419899761675e-05)
# ('sel loss', 4.8914463259279725e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 2.355200471356511e-05)
# ('sel loss', 2.680156147107482e-05)
# ('sel loss', 2.9642749577760696e-05)
# ('sel loss', 3.354292595759034e-05)
# ('sel loss', 3.413231344893575e-05)
# ('sel loss', 3.4492793492972854e-05)
# ('sel loss', 3.497082041576505e-05)
# ('sel loss', 3.81457176990807e-05)
# ('sel loss', 4.322977736592293e-05)
# ('sel loss', 5.1479400135576724e-05)
# in get_kymatio_pt
# ('get ptfile', 'modelB_krec0_start10.pt')
# ('get ptfile', 'modelB_krec1_start10.pt')
# ('get ptfile', 'modelB_krec2_start10.pt')
# ('get ptfile', 'modelB_krec3_start10.pt')
# ('get ptfile', 'modelB_krec4_start10.pt')
# ('get ptfile', 'modelB_krec5_start10.pt')
# ('get ptfile', 'modelB_krec6_start10.pt')
# ('get ptfile', 'modelB_krec7_start10.pt')
# ('get ptfile', 'modelB_krec8_start10.pt')
# ('get ptfile', 'modelB_krec9_start10.pt')
# ('sel loss', 2.566644223406911e-05)
# ('sel loss', 2.5784347672015427e-05)
# ('sel loss', 3.3198827877640725e-05)
# ('sel loss', 3.355289809405804e-05)
# ('sel loss', 3.4491356927901506e-05)
# ('sel loss', 3.8983800914138554e-05)
# ('sel loss', 4.1671879589557644e-05)
# ('sel loss', 4.642156884074211e-05)
# ('sel loss', 5.101946182549e-05)
# ('sel loss', 5.166700575500727e-05)
