# %%
import matplotlib.pyplot as plt
import do_plot_get2 as dpg
import numpy as np

import os,sys,datetime
import traceback

reload(dpg)

folds = 8

Ns = 256
S = 10
maxKrec=S
Ksel=maxKrec
droot1='./out/'
start0 = 10
hRUNFOL = './anisotur2a/bump_lbfgs_gpu_N256J5L8dj1dl4dk0dn2_maxkshift1_factr10maxite500maxcor20_initnormalstdbarx'
hptfile = 'modelC'

import scipy.io as sio
for fol in range(folds):
    kstart=fol+1
    imgs_pt=dpg.get_kymatio_pt(droot1,hRUNFOL,hptfile,Ns,kstart,maxKrec,Ksel,start0=start0,nbstart=10)
    ofile = './synthesis/anisotur2a_modelC_synthesis_ks' + str(kstart-1) +'.mat'
    sio.savemat (ofile , {'imgs':imgs_pt})
# Out:
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.00016540495678782463)
# ('sel loss', 0.00018181964755058287)
# ('sel loss', 0.00018268924206495284)
# ('sel loss', 0.00019464440643787384)
# ('sel loss', 0.00019547142088413238)
# ('sel loss', 0.00023007694631814956)
# ('sel loss', 0.00023083146661520004)
# ('sel loss', 0.00025166062638163565)
# ('sel loss', 0.0002571571432054043)
# ('sel loss', 0.00033044159412384035)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.00016365831717848778)
# ('sel loss', 0.00019715091213583946)
# ('sel loss', 0.00020059814676642417)
# ('sel loss', 0.00023380296304821967)
# ('sel loss', 0.00024044621735811234)
# ('sel loss', 0.00024336211383342742)
# ('sel loss', 0.0002443024143576622)
# ('sel loss', 0.00025135347619652747)
# ('sel loss', 0.00025893110781908033)
# ('sel loss', 0.0002742602117359638)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.00018124662339687346)
# ('sel loss', 0.00020207198336720468)
# ('sel loss', 0.0002151946723461151)
# ('sel loss', 0.0002512473240494728)
# ('sel loss', 0.00027158217504620553)
# ('sel loss', 0.00027435291558504106)
# ('sel loss', 0.0002822331339120865)
# ('sel loss', 0.0003104456514120102)
# ('sel loss', 0.00033079266548156737)
# ('sel loss', 0.00038038786500692366)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.0001882067695260048)
# ('sel loss', 0.00018909173086285592)
# ('sel loss', 0.0001992088556289673)
# ('sel loss', 0.00020553417503833772)
# ('sel loss', 0.0002075200714170933)
# ('sel loss', 0.00020924080163240433)
# ('sel loss', 0.00022119442000985147)
# ('sel loss', 0.0002309555746614933)
# ('sel loss', 0.00023744175210595132)
# ('sel loss', 0.0002580983191728592)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.00022941630333662034)
# ('sel loss', 0.000233320202678442)
# ('sel loss', 0.00023626316338777543)
# ('sel loss', 0.00025010215118527414)
# ('sel loss', 0.00025670617818832395)
# ('sel loss', 0.00026335390284657476)
# ('sel loss', 0.00029662404209375383)
# ('sel loss', 0.00030739132314920424)
# ('sel loss', 0.0003082803636789322)
# ('sel loss', 0.00035278681665658953)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.0001866111159324646)
# ('sel loss', 0.0001894904486835003)
# ('sel loss', 0.00020422838628292084)
# ('sel loss', 0.00020440740510821342)
# ('sel loss', 0.00020511865615844728)
# ('sel loss', 0.00020640375092625618)
# ('sel loss', 0.00021314945071935655)
# ('sel loss', 0.0002170814573764801)
# ('sel loss', 0.0002219066396355629)
# ('sel loss', 0.00029942665249109267)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.00017594065517187118)
# ('sel loss', 0.0001779555529356003)
# ('sel loss', 0.00018224230036139488)
# ('sel loss', 0.0001969507522881031)
# ('sel loss', 0.0002012263983488083)
# ('sel loss', 0.00021295536309480666)
# ('sel loss', 0.00024243960157036782)
# ('sel loss', 0.00024308091029524804)
# ('sel loss', 0.000260855071246624)
# ('sel loss', 0.0002657957561314106)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.00017182890325784684)
# ('sel loss', 0.00018697071820497513)
# ('sel loss', 0.00019166577607393265)
# ('sel loss', 0.00020497243851423265)
# ('sel loss', 0.00021546009927988051)
# ('sel loss', 0.0002475893124938011)
# ('sel loss', 0.00025094788521528243)
# ('sel loss', 0.0002621567994356155)
# ('sel loss', 0.0002653834968805313)
# ('sel loss', 0.0002825518697500229)
