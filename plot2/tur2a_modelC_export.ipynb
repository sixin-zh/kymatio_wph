# %%
import matplotlib.pyplot as plt
import do_plot_get2 as dpg
import numpy as np

import os,sys,datetime
import traceback

reload(dpg)

folds = 9

Ns = 256
S = 10
maxKrec=S
Ksel=maxKrec
droot1='./out/'
start0 = 10
hRUNFOL = './tur2a/bump_lbfgs_gpu_N256J5L8dj1dl4dk0dn2_maxkshift1_factr10maxite500maxcor20_initnormalstdbarx'
hptfile = 'modelC'

import scipy.io as sio
for fol in range(folds):
    kstart=fol+1
    imgs_pt=dpg.get_kymatio_pt(droot1,hRUNFOL,hptfile,Ns,kstart,maxKrec,Ksel,start0=start0,nbstart=10)
    ofile = './synthesis/tur2a_modelC_synthesis_ks' + str(kstart-1) +'.mat'
    sio.savemat (ofile , {'imgs':imgs_pt})
# Out:
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.0003670884296298027)
# ('sel loss', 0.0003722703829407692)
# ('sel loss', 0.0003734494373202324)
# ('sel loss', 0.0003738156706094742)
# ('sel loss', 0.0004037921503186226)
# ('sel loss', 0.0004293695092201233)
# ('sel loss', 0.000433332696557045)
# ('sel loss', 0.00044379554688930514)
# ('sel loss', 0.0004967884346842766)
# ('sel loss', 0.0005177038535475731)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.00027833424508571624)
# ('sel loss', 0.000310584120452404)
# ('sel loss', 0.00032225698232650756)
# ('sel loss', 0.0003670455515384674)
# ('sel loss', 0.0003839251771569252)
# ('sel loss', 0.00042723648250102996)
# ('sel loss', 0.00043898239731788636)
# ('sel loss', 0.00045932196080684663)
# ('sel loss', 0.0004892678186297416)
# ('sel loss', 0.000544782243669033)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.00023344628512859345)
# ('sel loss', 0.0002777436003088951)
# ('sel loss', 0.0002802504226565361)
# ('sel loss', 0.00029142104089260103)
# ('sel loss', 0.00029400480911135674)
# ('sel loss', 0.00029768947511911394)
# ('sel loss', 0.00030780386179685593)
# ('sel loss', 0.000327228419482708)
# ('sel loss', 0.000329982191324234)
# ('sel loss', 0.00044238317757844926)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.00033818423748016357)
# ('sel loss', 0.0003715392202138901)
# ('sel loss', 0.0003781615197658539)
# ('sel loss', 0.00038301460444927214)
# ('sel loss', 0.00038474459201097487)
# ('sel loss', 0.00038478054106235506)
# ('sel loss', 0.00038945414125919343)
# ('sel loss', 0.00039363447576761245)
# ('sel loss', 0.00041987258940935136)
# ('sel loss', 0.00042968571186065676)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.00029839906841516495)
# ('sel loss', 0.00031441174447536467)
# ('sel loss', 0.0003808316960930824)
# ('sel loss', 0.00039133675396442415)
# ('sel loss', 0.0003925284370779991)
# ('sel loss', 0.00039806559681892394)
# ('sel loss', 0.0004037029296159744)
# ('sel loss', 0.0004388157650828362)
# ('sel loss', 0.0004435919970273972)
# ('sel loss', 0.00046525120735168456)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.0002552756667137146)
# ('sel loss', 0.00027326848357915877)
# ('sel loss', 0.00030895296484231946)
# ('sel loss', 0.0003110312856733799)
# ('sel loss', 0.00035703059285879134)
# ('sel loss', 0.0003606204316020012)
# ('sel loss', 0.0003669115900993347)
# ('sel loss', 0.00039878129959106443)
# ('sel loss', 0.000415545292198658)
# ('sel loss', 0.00047039683908224107)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.0002585979364812374)
# ('sel loss', 0.00026034411042928694)
# ('sel loss', 0.0002729080058634281)
# ('sel loss', 0.0003083349764347076)
# ('sel loss', 0.00030972883105278014)
# ('sel loss', 0.00031622130423784254)
# ('sel loss', 0.0003322005271911621)
# ('sel loss', 0.0003350538015365601)
# ('sel loss', 0.0003419235348701477)
# ('sel loss', 0.0003462257236242294)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.00025019433349370956)
# ('sel loss', 0.00025903817266225814)
# ('sel loss', 0.0002652425691485405)
# ('sel loss', 0.00027419254183769226)
# ('sel loss', 0.00029228495433926584)
# ('sel loss', 0.00030450843274593353)
# ('sel loss', 0.0003137907385826111)
# ('sel loss', 0.0003216931596398354)
# ('sel loss', 0.00033077843487262727)
# ('sel loss', 0.0003778130933642387)
# in get_kymatio_pt
# ('get ptfile', 'modelC_krec0_start10.pt')
# ('get ptfile', 'modelC_krec1_start10.pt')
# ('get ptfile', 'modelC_krec2_start10.pt')
# ('get ptfile', 'modelC_krec3_start10.pt')
# ('get ptfile', 'modelC_krec4_start10.pt')
# ('get ptfile', 'modelC_krec5_start10.pt')
# ('get ptfile', 'modelC_krec6_start10.pt')
# ('get ptfile', 'modelC_krec7_start10.pt')
# ('get ptfile', 'modelC_krec8_start10.pt')
# ('get ptfile', 'modelC_krec9_start10.pt')
# ('sel loss', 0.00031999066472053527)
# ('sel loss', 0.0003255981206893921)
# ('sel loss', 0.0003275984898209572)
# ('sel loss', 0.00033982507884502413)
# ('sel loss', 0.0003528228774666786)
# ('sel loss', 0.0003547047823667526)
# ('sel loss', 0.0003750622272491455)
# ('sel loss', 0.0003917665034532547)
# ('sel loss', 0.0004380006715655327)
# ('sel loss', 0.00044423021376132965)
