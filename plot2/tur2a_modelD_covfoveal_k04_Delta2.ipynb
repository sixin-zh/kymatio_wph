# %%
# %matplotlib inline
import matlab.engine
import matlab
#eng = matlab.engine.start_matlab()  
eng = matlab.engine.connect_matlab()

# %%
import matplotlib.pyplot as plt
import do_plot_get2 as dpg
import numpy as np

import os,sys,datetime
import traceback

reload(dpg)

Ns=256
froot0= './data/'
testlabel = 'ns_randn4_test_N' + str(Ns)

ktest0=0
Stest=100

froot1 = './synthesis/'
modellabel = 'tur2a_modelD_synthesis'
folds=10
S = 10

J=5
L=8
Delta=2
kmin=0
kmax=4
jmin=1

cache=1
mode=3

# %%
from random import randint
fol_test_cov1 = []
fol_model_cov1 = []

# fol is for each model
try:
    # only 1 fold for test
    cov1re_test,cov1im_test = dpg.evalcovfoveal_test(eng,froot0,testlabel,ktest0,Stest,J,L,Delta,kmin,kmax,jmin,ext='matlab',cache=cache,mode=mode)
    cov1_test = cov1re_test + 1j * cov1im_test
    fol_test_cov1.append(cov1_test)
    for fol in range(folds):
        kstart=fol+1
        modelmat = modellabel + '_ks' + str(kstart-1)
        cov1re_model,cov1im_model = dpg.evalcovfoveal_test(eng,froot1,modelmat,0,S,J,L,Delta,kmin,kmax,jmin,ext='matlab',cache=cache,mode=mode,permute=0)
        cov1_model = cov1re_model + 1j * cov1im_model 
        fol_model_cov1.append(cov1_model)
        
    eng.quit()
except:
    var = traceback.format_exc()
    print "Unexpected error:", sys.exc_info()[0]
    eng.quit()
    print var
print('done')
# Out:
# ('load', './cache/stats/88/ns_randn4_test_N256_k0_100_evalcovfoveal3_test_582041.mat')
# last modified: Wed Nov 13 14:59:02 2019
# ('getori matlab fname=', 'tur2a_modelD_synthesis_ks0')
# load cached data: ./synthesis/tur2a_modelD_synthesis_ks0
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'tur2a_modelD_synthesis_ks1')
# load cached data: ./synthesis/tur2a_modelD_synthesis_ks1
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'tur2a_modelD_synthesis_ks2')
# load cached data: ./synthesis/tur2a_modelD_synthesis_ks2
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'tur2a_modelD_synthesis_ks3')
# load cached data: ./synthesis/tur2a_modelD_synthesis_ks3
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'tur2a_modelD_synthesis_ks4')
# load cached data: ./synthesis/tur2a_modelD_synthesis_ks4
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'tur2a_modelD_synthesis_ks5')
# load cached data: ./synthesis/tur2a_modelD_synthesis_ks5
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'tur2a_modelD_synthesis_ks6')
# load cached data: ./synthesis/tur2a_modelD_synthesis_ks6
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'tur2a_modelD_synthesis_ks7')
# load cached data: ./synthesis/tur2a_modelD_synthesis_ks7
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'tur2a_modelD_synthesis_ks8')
# load cached data: ./synthesis/tur2a_modelD_synthesis_ks8
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'tur2a_modelD_synthesis_ks9')
# load cached data: ./synthesis/tur2a_modelD_synthesis_ks9
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# done

# %%
reload(dpg)
fol_test_corr1,fol_model_corr1 = dpg.evaluate_corr(fol_test_cov1,fol_model_cov1,toplot=0)
# Out:
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))

# %%
reload(dpg)
dpg.compute_Kcorr_model(fol_test_corr1,fol_model_corr1)
# Out:
# epsilon^model:mean/std = 2.5e-01(+/-2.2e-02)
# [0.2320042587819517,
#  0.24413040040018705,
#  0.2673367454970728,
#  0.23642274467422864,
#  0.2532108427004277,
#  0.26184237055675375,
#  0.2429347922112965,
#  0.27005370396921213,
#  0.19545792249419622,
#  0.2670625726254139]
