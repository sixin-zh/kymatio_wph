# %%
# %matplotlib inline
import matlab.engine
import matlab
#eng = matlab.engine.start_matlab()  
eng = matlab.engine.connect_matlab()

# %%
import matplotlib.pyplot as plt
import do_plot_get2 as dpg
import numpy as np

import os,sys,datetime
import traceback

reload(dpg)

Ns=256
froot0= './data/'
testlabel = 'ns_randn4_test_N' + str(Ns)

ktest0=0
Stest=100

froot1 = './synthesis/'
modellabel = 'maxent_synthesis_tur2a'
folds=10
S = 10

J=5
L=8
Delta=2
kmin=0
kmax=4
jmin=1

cache=1
mode=3

# %%
from random import randint
fol_test_cov1 = []
fol_model_cov1 = []

# fol is for each model
try:
    # only 1 fold for test
    cov1re_test,cov1im_test = dpg.evalcovfoveal_test(eng,froot0,testlabel,ktest0,Stest,J,L,Delta,kmin,kmax,jmin,ext='matlab',cache=cache,mode=mode)
    cov1_test = cov1re_test + 1j * cov1im_test
    fol_test_cov1.append(cov1_test)
    for fol in range(folds):
        kstart=fol+1
        modelmat = modellabel + '_kb' + str(kstart)
        cov1re_model,cov1im_model = dpg.evalcovfoveal_test(eng,froot1,modelmat,0,S,J,L,Delta,kmin,kmax,jmin,ext='matlab',cache=cache,mode=mode)
        cov1_model = cov1re_model + 1j * cov1im_model 
        fol_model_cov1.append(cov1_model)
        
    eng.quit()
except:
    var = traceback.format_exc()
    print "Unexpected error:", sys.exc_info()[0]
    eng.quit()
    print var
print('done')
# Out:
# ('getori matlab fname=', 'ns_randn4_test_N256')
# load cached data: ./data/ns_randn4_test_N256
# ('test set size', 100)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'maxent_synthesis_tur2a_kb1')
# load cached data: ./synthesis/maxent_synthesis_tur2a_kb1
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'maxent_synthesis_tur2a_kb2')
# load cached data: ./synthesis/maxent_synthesis_tur2a_kb2
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'maxent_synthesis_tur2a_kb3')
# load cached data: ./synthesis/maxent_synthesis_tur2a_kb3
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'maxent_synthesis_tur2a_kb4')
# load cached data: ./synthesis/maxent_synthesis_tur2a_kb4
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'maxent_synthesis_tur2a_kb5')
# load cached data: ./synthesis/maxent_synthesis_tur2a_kb5
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'maxent_synthesis_tur2a_kb6')
# load cached data: ./synthesis/maxent_synthesis_tur2a_kb6
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'maxent_synthesis_tur2a_kb7')
# load cached data: ./synthesis/maxent_synthesis_tur2a_kb7
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'maxent_synthesis_tur2a_kb8')
# load cached data: ./synthesis/maxent_synthesis_tur2a_kb8
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'maxent_synthesis_tur2a_kb9')
# load cached data: ./synthesis/maxent_synthesis_tur2a_kb9
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'maxent_synthesis_tur2a_kb10')
# load cached data: ./synthesis/maxent_synthesis_tur2a_kb10
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# done

# %%
reload(dpg)
fol_test_corr1,fol_model_corr1 = dpg.evaluate_corr(fol_test_cov1,fol_model_cov1,toplot=0)
# Out:
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))

# %%
reload(dpg)
dpg.compute_Kcorr_model(fol_test_corr1,fol_model_corr1)
# Out:
# epsilon^model:mean/std = 8.2e-01(+/-6.9e-03)
# [0.818608356890908,
#  0.8189512240776511,
#  0.831650784226256,
#  0.834102953372627,
#  0.8214524151662063,
#  0.8166725152419433,
#  0.8320811352554385,
#  0.8146918273498562,
#  0.8217332121067547,
#  0.8307498678765359]
