# %%
# %matplotlib inline
import matlab.engine
import matlab
#eng = matlab.engine.start_matlab()  
eng = matlab.engine.connect_matlab()

# %%
import matplotlib.pyplot as plt
import do_plot_get2 as dpg
import numpy as np

import os,sys,datetime
import traceback

reload(dpg)

Ns=256
froot0= './data/'
testlabel = 'ns_randn4_test_N' + str(Ns)

ktest0=0
Stest=100

froot1 = './synthesis/'
modellabel = 'tur2a_modelB_synthesis'
folds=10
S = 10

J=5
L=8
Delta=2
kmin=0
kmax=4
jmin=1

cache=1
mode=3

# %%
from random import randint
fol_test_cov1 = []
fol_model_cov1 = []

# fol is for each model
try:
    # only 1 fold for test
    cov1re_test,cov1im_test = dpg.evalcovfoveal_test(eng,froot0,testlabel,ktest0,Stest,J,L,Delta,kmin,kmax,jmin,ext='matlab',cache=cache,mode=mode)
    cov1_test = cov1re_test + 1j * cov1im_test
    fol_test_cov1.append(cov1_test)
    for fol in range(folds):
        kstart=fol+1
        modelmat = modellabel + '_ks' + str(kstart-1)
        cov1re_model,cov1im_model = dpg.evalcovfoveal_test(eng,froot1,modelmat,0,S,J,L,Delta,kmin,kmax,jmin,ext='matlab',cache=cache,mode=mode,permute=0)
        cov1_model = cov1re_model + 1j * cov1im_model 
        fol_model_cov1.append(cov1_model)
        
    eng.quit()
except:
    var = traceback.format_exc()
    print "Unexpected error:", sys.exc_info()[0]
    eng.quit()
    print var
print('done')
# Out:
# ('load', './cache/stats/88/ns_randn4_test_N256_k0_100_evalcovfoveal3_test_582041.mat')
# last modified: Wed Nov 13 14:59:02 2019
# ('load', './cache/stats/68/tur2a_modelB_synthesis_ks0_k0_10_evalcovfoveal3_test_582041.mat')
# last modified: Wed Nov 13 19:55:38 2019
# ('load', './cache/stats/67/tur2a_modelB_synthesis_ks1_k0_10_evalcovfoveal3_test_582041.mat')
# last modified: Wed Nov 13 21:52:37 2019
# ('load', './cache/stats/25/tur2a_modelB_synthesis_ks2_k0_10_evalcovfoveal3_test_582041.mat')
# last modified: Wed Nov 13 22:04:57 2019
# ('load', './cache/stats/17/tur2a_modelB_synthesis_ks3_k0_10_evalcovfoveal3_test_582041.mat')
# last modified: Wed Nov 13 22:12:27 2019
# ('load', './cache/stats/77/tur2a_modelB_synthesis_ks4_k0_10_evalcovfoveal3_test_582041.mat')
# last modified: Wed Nov 13 22:19:35 2019
# ('load', './cache/stats/80/tur2a_modelB_synthesis_ks5_k0_10_evalcovfoveal3_test_582041.mat')
# last modified: Wed Nov 13 22:26:46 2019
# ('getori matlab fname=', 'tur2a_modelB_synthesis_ks6')
# load cached data: ./synthesis/tur2a_modelB_synthesis_ks6
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'tur2a_modelB_synthesis_ks7')
# load cached data: ./synthesis/tur2a_modelB_synthesis_ks7
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'tur2a_modelB_synthesis_ks8')
# load cached data: ./synthesis/tur2a_modelB_synthesis_ks8
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# ('getori matlab fname=', 'tur2a_modelB_synthesis_ks9')
# load cached data: ./synthesis/tur2a_modelB_synthesis_ks9
# ('test set size', 10)
# ('run matlab to eval bumpcovfoveal3 with klim ... use nbcores=', 12)
# done

# %%
reload(dpg)
fol_test_corr1,fol_model_corr1 = dpg.evaluate_corr(fol_test_cov1,fol_model_cov1,toplot=0)
# Out:
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))
# (8025, 8025)
# ('invdiaghalf shape', (8025, 8025))

# %%
reload(dpg)
dpg.compute_Kcorr_model(fol_test_corr1,fol_model_corr1)
# Out:
# epsilon^model:mean/std = 2.9e-01(+/-1.6e-02)
# [0.27224839106791054,
#  0.28632939089333753,
#  0.3143430326996167,
#  0.271093057117981,
#  0.2700488017196627,
#  0.28190443161987555,
#  0.3038170928048266,
#  0.29702123279380155,
#  0.3106216664759491,
#  0.28680733155677823]
