# %%
import matplotlib.pyplot as plt
import do_plot_get2 as dpg
import numpy as np

import os,sys,datetime
import traceback

reload(dpg)

folds = 10

Ns = 256
S = 10
maxKrec=S
Ksel=maxKrec
droot1='./out/'
start0 = 10
hRUNFOL = './mrw2dd/bump_lbfgs_gpu_N256J5L8dj1dldk0_factr10maxite500maxcor20_initnormalstdbarx'
hptfile = 'eval_wph2_isonoref_norml_stdnorm1'

import scipy.io as sio
for fol in range(folds):
    kstart=fol+1
    imgs_pt=dpg.get_kymatio_pt(droot1,hRUNFOL,hptfile,Ns,kstart,maxKrec,Ksel,start0=start0,nbstart=10)
    ofile = './synthesis/mrw2dd_modelD_synthesis_ks' + str(kstart-1) +'.mat'
    sio.savemat (ofile , {'imgs':imgs_pt})
# Out:
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start10.pt')
# ('sel loss', 1.0166620995732955e-07)
# ('sel loss', 1.0431114787934349e-07)
# ('sel loss', 1.4895620552124454e-07)
# ('sel loss', 1.5017943951534108e-07)
# ('sel loss', 1.8163475033361464e-07)
# ('sel loss', 2.0733077690238134e-07)
# ('sel loss', 2.1335004930733702e-07)
# ('sel loss', 2.148667408619076e-07)
# ('sel loss', 2.2614167392021045e-07)
# ('sel loss', 2.443857738398947e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start10.pt')
# ('sel loss', 1.4777020624023862e-07)
# ('sel loss', 1.8068843928631396e-07)
# ('sel loss', 1.867376886366401e-07)
# ('sel loss', 1.9197545043425634e-07)
# ('sel loss', 1.9530403733369894e-07)
# ('sel loss', 1.967923526535742e-07)
# ('sel loss', 2.0251723981346003e-07)
# ('sel loss', 2.1578685846179724e-07)
# ('sel loss', 2.8336115065030754e-07)
# ('sel loss', 4.726904444396496e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start10.pt')
# ('sel loss', 7.398037269013002e-08)
# ('sel loss', 8.0189593063551e-08)
# ('sel loss', 1.3888147805118932e-07)
# ('sel loss', 1.3909005247114692e-07)
# ('sel loss', 1.440318919776473e-07)
# ('sel loss', 1.4590099453926086e-07)
# ('sel loss', 2.97488622891251e-07)
# ('sel loss', 3.5899771319236604e-07)
# ('sel loss', 5.544297528103925e-07)
# ('sel loss', 5.899055395275354e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start10.pt')
# ('sel loss', 8.450186214759014e-08)
# ('sel loss', 9.841503924690187e-08)
# ('sel loss', 1.0093504897668026e-07)
# ('sel loss', 1.1338514013914391e-07)
# ('sel loss', 1.2520033124019392e-07)
# ('sel loss', 1.352889921690803e-07)
# ('sel loss', 1.3621733160107397e-07)
# ('sel loss', 1.511335176473949e-07)
# ('sel loss', 1.653393883316312e-07)
# ('sel loss', 1.867883838713169e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start10.pt')
# ('sel loss', 6.407068212865852e-08)
# ('sel loss', 6.86403382132994e-08)
# ('sel loss', 9.500601663603447e-08)
# ('sel loss', 1.384775350743439e-07)
# ('sel loss', 1.5144835742830765e-07)
# ('sel loss', 1.9246142983320168e-07)
# ('sel loss', 2.0621801013476216e-07)
# ('sel loss', 2.526885145925917e-07)
# ('sel loss', 2.855824459402356e-07)
# ('sel loss', 4.29794927185867e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start10.pt')
# ('sel loss', 6.655983270320575e-08)
# ('sel loss', 8.088655704341364e-08)
# ('sel loss', 1.231287751579657e-07)
# ('sel loss', 1.2326387150096707e-07)
# ('sel loss', 1.3413684428087435e-07)
# ('sel loss', 1.4238586118153762e-07)
# ('sel loss', 2.1004974769311958e-07)
# ('sel loss', 2.555790888436604e-07)
# ('sel loss', 3.0215762308216654e-07)
# ('sel loss', 3.069281228817999e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start10.pt')
# ('sel loss', 1.046670695359353e-07)
# ('sel loss', 1.532761598355137e-07)
# ('sel loss', 1.6128062270581723e-07)
# ('sel loss', 1.8330483726458623e-07)
# ('sel loss', 1.9700353732332587e-07)
# ('sel loss', 2.90883363049943e-07)
# ('sel loss', 2.95408462989144e-07)
# ('sel loss', 3.053995533264242e-07)
# ('sel loss', 3.3407741284463555e-07)
# ('sel loss', 5.834288458572701e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start10.pt')
# ('sel loss', 7.042016022751341e-08)
# ('sel loss', 8.046028597163968e-08)
# ('sel loss', 8.134337804222014e-08)
# ('sel loss', 8.387271009269171e-08)
# ('sel loss', 1.3325643521966413e-07)
# ('sel loss', 1.342138057225384e-07)
# ('sel loss', 1.4275649846240412e-07)
# ('sel loss', 1.5220701243379154e-07)
# ('sel loss', 1.7768594261724503e-07)
# ('sel loss', 2.1601677872240543e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start10.pt')
# ('sel loss', 1.5255563084792812e-07)
# ('sel loss', 1.543361213407479e-07)
# ('sel loss', 1.780258389771916e-07)
# ('sel loss', 1.783142943168059e-07)
# ('sel loss', 1.862486715253908e-07)
# ('sel loss', 2.571017284935806e-07)
# ('sel loss', 2.801272785291076e-07)
# ('sel loss', 2.9006449040025475e-07)
# ('sel loss', 3.161322820233181e-07)
# ('sel loss', 4.760160300065763e-07)
# in get_kymatio_pt
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec0_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec1_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec2_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec3_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec4_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec5_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec6_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec7_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec8_start10.pt')
# ('get ptfile', 'eval_wph2_isonoref_norml_stdnorm1_krec9_start10.pt')
# ('sel loss', 1.394147693645209e-07)
# ('sel loss', 1.8825514416676015e-07)
# ('sel loss', 2.0223864339641295e-07)
# ('sel loss', 2.0677392967627383e-07)
# ('sel loss', 2.2034229914424942e-07)
# ('sel loss', 2.2522239305544646e-07)
# ('sel loss', 2.4609704269096255e-07)
# ('sel loss', 2.829382719937712e-07)
# ('sel loss', 3.172432116116397e-07)
# ('sel loss', 3.213012678315863e-07)
